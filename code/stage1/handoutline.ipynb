# %%
import cv2 as cv
import numpy as np

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
 
img = cv2.imread("palm.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
canny = cv2.Canny(img, 100, 200)

titles = ['image', 'canny']
images = [img, canny]
for i in range(2):
    plt.subplot(1, 2, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
from gtts import gTTS
import os
mytext = 'Welcome to geeksforgeeks!'
language = 'en'
myobj = gTTS(text=mytext, lang=language, slow=False)
myobj.save("welcome.mp3")
os.system("mpg321 welcome.mp3")
# Out:
# 1

# %%
import gtts
from playsound import playsound
# make request to google to get synthesis
tts = gtts.gTTS("Hello world")
# save the audio file
tts.save("hello.mp3")
# play the audio file
playsound("hello.mp3")
# Out:
#     Error 259 for command:
#         play hello.mp3 wait
#     The driver cannot recognize the specified command parameter.
#
#     Error 263 for command:
#         close hello.mp3
#     The specified device is not open or is not recognized by MCI.
# Failed to close the file: hello.mp3
# ---------------------------------------------------------------------------
# PlaysoundException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11164/3869818326.py in <module>
#       6 tts.save("hello.mp3")
#       7 # play the audio file
# ----> 8 playsound("hello.mp3")
#
# ~\anaconda3\envs\tfgpu\lib\site-packages\playsound.py in _playsoundWin(sound, block)
#      71         logger.debug('Starting')
#      72         winCommand(u'open {}'.format(sound))
# ---> 73         winCommand(u'play {}{}'.format(sound, ' wait' if block else ''))
#      74         logger.debug('Returning')
#      75     finally:
#
# ~\anaconda3\envs\tfgpu\lib\site-packages\playsound.py in winCommand(*command)
#      62                                 '\n    ' + errorBuffer.raw.decode('utf-16').rstrip('\0'))
#      63             logger.error(exceptionMessage)
# ---> 64             raise PlaysoundException(exceptionMessage)
#      65         return buf.value
#      66
#
# PlaysoundException:
#     Error 259 for command:
#         play hello.mp3 wait
#     The driver cannot recognize the specified command parameter.

# %%
import pyttsx3

# %%
# initialize Text-to-speech engine
engine = pyttsx3.init()
# slower
engine.setProperty("rate", 150)

# %%
# convert this text to speech
text = "Azharuddin is a good boy"
engine.say(text)
# play the speech
engine.runAndWait()
