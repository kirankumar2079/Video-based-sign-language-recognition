# %%
from imutils import paths 
import face_recognition
import pickle
import cv2
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7208/1732661901.py in <module>
#       1 from imutils import paths
# ----> 2 import face_recognition
#       3 import pickle
#       4 import cv2
#       5 import os
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
#get paths of each file in folder named Images
#Images here that contains data(folders of various people)
imagePath = list(paths.list_images('Facedata'))
kEncodings = []
kNames = []
print(imagePath)
# Out:
# ['Facedata\\Aaron_Eckhart\\Aaron_Eckhart_0001.jpg', 'Facedata\\Aaron_Guiel\\Aaron_Guiel_0001.jpg', 'Facedata\\Aaron_Patterson\\Aaron_Patterson_0001.jpg', 'Facedata\\Aaron_Peirsol\\Aaron_Peirsol_0001.jpg', 'Facedata\\Aaron_Peirsol\\Aaron_Peirsol_0002.jpg', 'Facedata\\Aaron_Peirsol\\Aaron_Peirsol_0003.jpg', 'Facedata\\Aaron_Peirsol\\Aaron_Peirsol_0004.jpg', 'Facedata\\Aaron_Pena\\Aaron_Pena_0001.jpg', 'Facedata\\Aaron_Sorkin\\Aaron_Sorkin_0001.jpg', 'Facedata\\Aaron_Sorkin\\Aaron_Sorkin_0002.jpg', 'Facedata\\Aaron_Tippin\\Aaron_Tippin_0001.jpg', 'Facedata\\Abbas_Kiarostami\\Abbas_Kiarostami_0001.jpg', 'Facedata\\Abba_Eban\\Abba_Eban_0001.jpg', 'Facedata\\Abdel_Aziz_Al-Hakim\\Abdel_Aziz_Al-Hakim_0001.jpg', 'Facedata\\Abdel_Madi_Shabneh\\Abdel_Madi_Shabneh_0001.jpg', 'Facedata\\Abdel_Nasser_Assidi\\Abdel_Nasser_Assidi_0001.jpg', 'Facedata\\Abdel_Nasser_Assidi\\Abdel_Nasser_Assidi_0002.jpg', 'Facedata\\Abdoulaye_Wade\\Abdoulaye_Wade_0001.jpg', 'Facedata\\Abdoulaye_Wade\\Abdoulaye_Wade_0002.jpg', 'Facedata\\Abdoulaye_Wade\\Abdoulaye_Wade_0003.jpg', 'Facedata\\Abdoulaye_Wade\\Abdoulaye_Wade_0004.jpg', 'Facedata\\Abdulaziz_Kamilov\\Abdulaziz_Kamilov_0001.jpg', 'Facedata\\Abdullah\\Abdullah_0001.jpg', 'Facedata\\Abdullah\\Abdullah_0002.jpg', 'Facedata\\Abdullah\\Abdullah_0003.jpg', 'Facedata\\Abdullah\\Abdullah_0004.jpg', 'Facedata\\Abdullah_Ahmad_Badawi\\Abdullah_Ahmad_Badawi_0001.jpg', 'Facedata\\Abdullah_al-Attiyah\\Abdullah_al-Attiyah_0001.jpg', 'Facedata\\Abdullah_al-Attiyah\\Abdullah_al-Attiyah_0002.jpg', 'Facedata\\Abdullah_al-Attiyah\\Abdullah_al-Attiyah_0003.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0001.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0002.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0003.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0004.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0005.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0006.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0007.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0008.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0009.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0010.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0011.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0012.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0013.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0014.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0015.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0016.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0017.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0018.jpg', 'Facedata\\Abdullah_Gul\\Abdullah_Gul_0019.jpg', 'Facedata\\Abdullah_Nasseef\\Abdullah_Nasseef_0001.jpg', 'Facedata\\Abdullatif_Sener\\Abdullatif_Sener_0001.jpg', 'Facedata\\Abdullatif_Sener\\Abdullatif_Sener_0002.jpg', 'Facedata\\Abdul_Majeed_Shobokshi\\Abdul_Majeed_Shobokshi_0001.jpg', 'Facedata\\Abdul_Rahman\\Abdul_Rahman_0001.jpg', 'Facedata\\Abel_Aguilar\\Abel_Aguilar_0001.jpg', 'Facedata\\Abel_Pacheco\\Abel_Pacheco_0001.jpg', 'Facedata\\Abel_Pacheco\\Abel_Pacheco_0002.jpg', 'Facedata\\Abel_Pacheco\\Abel_Pacheco_0003.jpg', 'Facedata\\Abel_Pacheco\\Abel_Pacheco_0004.jpg', 'Facedata\\Abid_Hamid_Mahmud_Al-Tikriti\\Abid_Hamid_Mahmud_Al-Tikriti_0001.jpg', 'Facedata\\Abid_Hamid_Mahmud_Al-Tikriti\\Abid_Hamid_Mahmud_Al-Tikriti_0002.jpg', 'Facedata\\Abid_Hamid_Mahmud_Al-Tikriti\\Abid_Hamid_Mahmud_Al-Tikriti_0003.jpg', 'Facedata\\Abner_Martinez\\Abner_Martinez_0001.jpg', 'Facedata\\Abraham_Foxman\\Abraham_Foxman_0001.jpg', 'Facedata\\Aby_Har-Even\\Aby_Har-Even_0001.jpg', 'Facedata\\Adam_Ant\\Adam_Ant_0001.jpg', 'Facedata\\Adam_Freier\\Adam_Freier_0001.jpg', 'Facedata\\Adam_Herbert\\Adam_Herbert_0001.jpg', 'Facedata\\Adam_Kennedy\\Adam_Kennedy_0001.jpg', 'Facedata\\Adam_Mair\\Adam_Mair_0001.jpg', 'Facedata\\Adam_Rich\\Adam_Rich_0001.jpg', 'Facedata\\Adam_Sandler\\Adam_Sandler_0001.jpg', 'Facedata\\Adam_Sandler\\Adam_Sandler_0002.jpg', 'Facedata\\Adam_Sandler\\Adam_Sandler_0003.jpg', 'Facedata\\Adam_Sandler\\Adam_Sandler_0004.jpg', 'Facedata\\Adam_Scott\\Adam_Scott_0001.jpg', 'Facedata\\Adam_Scott\\Adam_Scott ...

# %%
# loop over the image paths
for (i, ip) in enumerate(imagePath):
    # extract the person name from the image path
    name = ip.split(os.path.sep)[-2]
    # load the input image and convert it from BGR
    image = cv2.imread(ip)
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
import cv2

# Load the cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
# Read the input image
img = cv2.imread('test1.jpg')
imS = cv2. resize(img, (960, 540)) 
# Convert into grayscale
gray = cv2.cvtColor(imS, cv2.COLOR_BGR2GRAY)
# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.1, 4)
# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(imS, (x, y), (x+w, y+h), (255, 0, 0), 2)
# Display the output
cv2.imshow('img', imS)
cv2.waitKey()
# Out:
# 113

# %%
import cv2
 

img = cv2.imread("test.jpg", cv2.IMREAD_COLOR)
imS = cv2. resize(im, (960, 540)) 

cv2.imshow("Cute Kitens", imS)
 

cv2.waitKey(0)

cv2.destroyAllWindows()
