# %%
from fer import FER
import matplotlib.pyplot as plt 
# %matplotlib inline

test_image_one = plt.imread("test.jpg")
emo_detector = FER(mtcnn=True)
# Capture all the emotions on the image
captured_emotions = emo_detector.detect_emotions(test_image_one)
# Print all captured emotions with the image
print(captured_emotions)
plt.imshow(test_image_one)

# Use the top Emotion() function to call for the dominant emotion in the image
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image_one)
print(dominant_emotion, emotion_score)
# Out:
# [{'box': [756, 425, 725, 883], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.97, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.02}}, {'box': [1152, 2261, 41, 47], 'emotions': {'angry': 0.16, 'disgust': 0.0, 'fear': 0.08, 'happy': 0.18, 'sad': 0.15, 'surprise': 0.0, 'neutral': 0.43}}]
# happy 0.97

# %%
pip install FER
# Out:
# Collecting FER
#   Using cached fer-22.4.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: matplotlib in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from FER) (3.5.1)
# Collecting mtcnn>=0.1.1
#   Using cached mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
# Requirement already satisfied: opencv-contrib-python in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from FER) (4.5.5.62)
# Requirement already satisfied: requests in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from FER) (2.27.1)
# Requirement already satisfied: tqdm in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from FER) (4.63.0)
# Requirement already satisfied: keras>=2.0.0 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from FER) (2.7.0)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from mtcnn>=0.1.1->FER) (4.5.5.62)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from opencv-python>=4.1.0->mtcnn>=0.1.1->FER) (1.22.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from matplotlib->FER) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from matplotlib->FER) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from matplotlib->FER) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from matplotlib->FER) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from matplotlib->FER) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from matplotlib->FER) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from matplotlib->FER) (1.3.1)
# Requirement already satisfied: six>=1.5 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from python-dateutil>=2.7->matplotlib->FER) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from requests->FER) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from requests->FER) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from requests->FER) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from requests->FER) (2.0.11)
# Requirement already satisfied: colorama in c:\users\azhar\anaconda3\envs\tfgpu\lib\site-packages (from tqdm->FER) (0.4.4)
# Installing collected packages: mtcnn, FER
# Successfully installed FER-22.4.0 mtcnn-0.1.1
# Note: you may need to restart the kernel to use updated packages.
